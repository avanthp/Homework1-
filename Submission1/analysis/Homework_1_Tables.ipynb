# %%
# Importing packages 
import pandas as pd
plan_data = pd.read_csv('../../Data/Output/plan_data.csv')
# Out:
#         Contract ID  Plan ID                        Organization Type  \
# 0             90091      NaN                         HCPP - 1833 Cost
# 1             E0654    801.0  Employer/Union Only Direct Contract PDP
# 2             E0654    801.0  Employer/Union Only Direct Contract PDP
# 3             E0654    801.0  Employer/Union Only Direct Contract PDP
# 4             E0654    801.0  Employer/Union Only Direct Contract PDP
# ...             ...      ...                                      ...
# 2251618       S9701    806.0          Medicare Prescription Drug Plan
# 2251619       S9701    806.0          Medicare Prescription Drug Plan
# 2251620       S9701    806.0          Medicare Prescription Drug Plan
# 2251621       S9701    806.0          Medicare Prescription Drug Plan
# 2251622       S9701    806.0          Medicare Prescription Drug Plan
#
#                                        Plan Type Offers Part D SNP Plan EGHP  \
# 0                               HCPP - 1833 Cost            No       No   No
# 1        Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 2        Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 3        Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 4        Employer/Union Only Direct Contract PDP           Yes       No  Yes
# ...                                          ...           ...      ...  ...
# 2251618          Medicare Prescription Drug Plan           Yes       No  Yes
# 2251619          Medicare Prescription Drug Plan           Yes       No  Yes
# 2251620          Medicare Prescription Drug Plan           Yes       No  Yes
# 2251621          Medicare Prescription Drug Plan           Yes       No  Yes
# 2251622          Medicare Prescription Drug Plan           Yes       No  Yes
#
#                                         Organization Name  \
# 0        UNITED MINE WORKERS OF AMERICA HLTH & RETIREMENT
# 1                   IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 2                   IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 3                   IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 4                   IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# ...                                                   ...
# 2251618                       DEAN HEALTH INSURANCE, INC.
# 2251619                       DEAN HEALTH INSURANCE, INC.
# 2251620                       DEAN HEALTH INSURANCE, INC.
# 2251621                       DEAN HEALTH INSURANCE, INC.
# 2251622                       DEAN HEALTH INSURANCE, INC.
#
#                                Organization Marketing Name  \
# 0        United Mine Workers of America Health & Retire...
# 1        TEAMStar Medicare Part D Prescription Drug Pro...
# 2        TEAMStar Medicare Part D Prescription Drug Pro...
# 3        TEAMStar Medicare Part D Prescription Drug Pro...
# 4        TEAMStar Medicare Part D Prescription Drug Pro...
# ...                                                    ...
# 2251618                                 Navitus MedicareRx
# 2251619                                 Navitus MedicareRx
# 2251620                                 Navitus MedicareRx
# 2251621                                 Navitus MedicareRx
# 2251622                                 Navitus MedicareRx
#
#                                                  Plan Name  \
# 0                                                      NaN
# 1        IBT Voluntary Employee Benefits Trust (Employe...
# 2        IBT Voluntary Employee Benefits Trust (Employe...
# 3        IBT Voluntary Employee Benefits Trust (Employe...
# 4        IBT Voluntary Employee Benefits Trust (Employe...
# ...                                                    ...
# 2251618                           Navitus MedicareRx (PDP)
# 2251619                           Navitus MedicareRx (PDP)
# 2251620                           Navitus MedicareRx (PDP)
# 2251621                           Navitus MedicareRx (PDP)
# 2251622                           Navitus MedicareRx (PDP)
#
#                            Parent Organization Contract Effective Date  \
# 0             UMWA Health and Retirement Funds      02/01/1974 0:00:00
# 1        IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00
# 2        IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00
# 3        IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00
# 4        IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00
# ...                                        ...                     ...
# 2251618             SSM Healthcare Corporation      01/01/2015 0:00:00
# 2251619             SSM Healthcare Corporation      01/01/2015 0:00:00
# 2251620             SSM Healthcare Corporation      01/01/2015 0:00:00
# 2251621             SSM Healthcare Corporation      01/01/2015 0:00:00
# 2251622             SSM Healthcare Corporation      01/01/2015 0:00:00
#
#          SSA State County Code  FIPS State County Code State      County  \
# 0                          NaN                     NaN   NaN         NaN
# 1                      58160.0                     NaN   NaN         NaN
# 2                      61000.0                     NaN   NaN         NaN
# 3                      96001.0                     NaN   NaN         NaN
# 4                       2275.0                     NaN   NaN         NaN
# ...                        ...                     ...   ...         ...
# 2251618                53180.0                 56037.0    WY  Sweetwater
# 2251619                53190.0                 56039.0    WY       Teton
# 2251620                53200.0                 56041.0    WY       Uinta
# 2251621                53210.0                 56043.0    WY    Washakie
# 2251622                53220.0                 56045.0    WY      Weston
#
#         Enrollment
# 0              NaN
# 1                *
# 2                *
# 3                *
# 4                *
# ...            ...
# 2251618          *
# 2251619          *
# 2251620          *
# 2251621          *
# 2251622          *
#
# [2251623 rows x 17 columns]

# %%
plans_per_type = plan_data.pivot_table(index='Plan Type', values='Plan ID', aggfunc='count')
plans_per_type = plans_per_type.sort_values(by='Plan ID', ascending=False)

plans_per_type
# Out:
#                                          Plan ID
# Plan Type
# Medicare Prescription Drug Plan           991457
# Local PPO                                 704993
# HMO/HMOPOS                                479275
# Employer/Union Only Direct Contract PDP    25630
# Regional PPO                               17578
# PFFS                                       13658
# 1876 Cost                                   7157
# MSA                                         6518
# Medicare-Medicaid Plan HMO/HMOPOS           4130
# National PACE                               1216
# HCPP - 1833 Cost                               0
# Pilot                                          0
